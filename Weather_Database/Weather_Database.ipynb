# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Check info from API
## city_url = url + "&q=" + "Boston"
## city_weather = requests.get(city_url)
## city_weather.json()

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ostrovnoy
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | grand gaube
# Processing Record 4 of Set 1 | alofi
# Processing Record 5 of Set 1 | luderitz
# Processing Record 6 of Set 1 | lompoc
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | skibbereen
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | husavik
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 1 | fortuna
# Processing Record 18 of Set 1 | hearst
# Processing Record 19 of Set 1 | leningradskiy
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | baykit
# Processing Record 22 of Set 1 | angoram
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | yenagoa
# Processing Record 25 of Set 1 | thinadhoo
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | tamandare
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | glamoc
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | abong mbang
# Processing Record 33 of Set 1 | doume
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | fandriana
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | vestmannaeyjar
# Processing Record 38 of Set 1 | ankang
# Processing Record 39 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | bac lieu
# Processing Record 44 of Set 1 | vanavara
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 1 | talnakh
# Processing Record 48 of Set 1 | elizabeth city
# Processing Record 49 of Set 1 | camopi
# Processing Record 50 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | cockburn town
# Processing Record 3 of Set 2 | coihaique
# Processing Record 4 of Set 2 | mazara del vallo
# Processing Record 5 of Set 2 | san quintin
# Processing Record 6 of Set 2 | smithers
# Processing Record 7 of Set 2 | wewak
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | saint-philippe
# Processing Record 11 of Set 2 | parry sound
# Processing Record 12 of Set 2 | trat
# Processing Record 13 of Set 2 | road town
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 2 | broken hill
# Processing Record 17 of Set 2 | vao
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | manadhoo
# Processing Record 20 of Set 2 | cabo san lucas
# Processing Record 21 of Set 2 | abu dhabi
# Processing Record 22 of Set 2 | mar del plata
# Processing Record 23 of Set 2 | colon
# Processing Record 24 of Set 2 | kavieng
# Processing Record 25 of Set 2 | foumban
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | haines junction
# Processing Record 30 of Set 2 | inongo
# Processing Record 31 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 2 | severo-kurilsk
# Processing Record 33 of Set 2 | aykhal
# Processing Record 34 of Set 2 | tianpeng
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | tokmak
# Processing Record 37 of Set 2 | makakilo city
# Processing Record 38 of Set 2 | bengkulu
# Processing Record 39 of Set 2 | saint-joseph
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | achisay
# City not found. Skipping...
# Processing Record 43 of Set 2 | carnarvon
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | ferkessedougou
# Processing Record 46 of Set 2 | noyabrsk
# Processing Record 47 of Set 2 | halifax
# Processing Record 48 of Set 2 | lac du bonnet
# Processing Record 49 of Set 2 | bambous virieux
# Processing Record 50 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 3 | punta arenas
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | katsuura
# Processing Record 4 of Set 3 | maniitsoq
# Processing Record 5 of Set 3 | vanimo
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | gasa
# Processing Record 8 of Set 3 | vaini
# Processing Record 9 of Set 3 | asau
# Processing Record 10 of Set 3 | edson
# Processing Record 11 of Set 3 | tongchuan
# Processing Record 12 of Set 3 | bethel
# Processing Record 13 of Set 3 | zhigansk
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | antalaha
# Processing Record 16 of Set 3 | gazanjyk
# Processing Record 17 of Set 3 | guilin
# Processing Record 18 of Set 3 | lumeje
# Processing Record 19 of Set 3 | saint-lo
# Processing Record 20 of Set 3 | lorengau
# Processing Record 21 of Set 3 | iqaluit
# Processing Record 22 of Set 3 | asfi
# Processing Record 23 of Set 3 | naryan-mar
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | songea
# Processing Record 26 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 3 | tangier
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | east london
# Processing Record 30 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 3 | shubarshi
# Processing Record 32 of Set 3 | clones
# Processing Record 33 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 3 | faanui
# Processing Record 35 of Set 3 | zlatoust
# Processing Record 36 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 3 | danielskuil
# Processing Record 38 of Set 3 | ancud
# Processing Record 39 of Set 3 | korla
# Processing Record 40 of Set 3 | shimoda
# Processing Record 41 of Set 3 | bluff
# Processing Record 42 of Set 3 | kirakira
# Processing Record 43 of Set 3 | caravelas
# Processing Record 44 of Set 3 | kieta
# Processing Record 45 of Set 3 | mantua
# Processing Record 46 of Set 3 | nanortalik
# Processing Record 47 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 48 of Set 3 | lagoa
# Processing Record 49 of Set 3 | sistranda
# Processing Record 50 of Set 3 | chake chake
# Processing Record 1 of Set 4 | pisco
# Processing Record 2 of Set 4 | domoni
# Processing Record 3 of Set 4 | jalu
# Processing Record 4 of Set 4 | yar-sale
# Processing Record 5 of Set 4 | gazni
# City not found. Skipping...
# Processing Record 6 of Set 4 | khatanga
# Processing Record 7 of Set 4 | pevek
# Processing Record 8 of Set 4 | niedercorn
# Processing Record 9 of Set 4 | myre
# Processing Record 10 of Set 4 | anadyr
# Processing Record 11 of Set 4 | barra do garcas
# Processing Record 12 of Set 4 | athabasca
# Processing Record 13 of Set 4 | isla aguada
# Processing Record 14 of Set 4 | sainte-maxime
# Processing Record 15 of Set 4 | pudozh
# Processing Record 16 of Set 4 | bilsanda
# Processing Record 17 of Set 4 | umm lajj
# Processing Record 18 of Set 4 | hofn
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 4 | hobart
# Processing Record 21 of Set 4 | elko
# Processing Record 22 of Set 4 | fairbanks
# Processing Record 23 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | quatre cocos
# Processing Record 26 of Set 4 | vila franca do campo
# Processing Record 27 of Set 4 | comodoro rivadavia
# Processing Record 28 of Set 4 | tarogong
# Processing Record 29 of Set 4 | santo tomas
# Processing Record 30 of Set 4 | barrow
# Processing Record 31 of Set 4 | seoul
# Processing Record 32 of Set 4 | mana
# Processing Record 33 of Set 4 | namibe
# Processing Record 34 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 35 of Set 4 | kano
# Processing Record 36 of Set 4 | renfrew
# Processing Record 37 of Set 4 | kenai
# Processing Record 38 of Set 4 | puerto colombia
# Processing Record 39 of Set 4 | krasnoselkup
# Processing Record 40 of Set 4 | provideniya
# Processing Record 41 of Set 4 | avera
# Processing Record 42 of Set 4 | cabedelo
# Processing Record 43 of Set 4 | baker city
# Processing Record 44 of Set 4 | morros
# Processing Record 45 of Set 4 | yinchuan
# Processing Record 46 of Set 4 | kaitangata
# Processing Record 47 of Set 4 | esperance
# Processing Record 48 of Set 4 | la ronge
# Processing Record 49 of Set 4 | nikolskoye
# Processing Record 50 of Set 4 | chicama
# Processing Record 1 of Set 5 | sambava
# Processing Record 2 of Set 5 | bougouni
# Processing Record 3 of Set 5 | pandamatenga
# Processing Record 4 of Set 5 | labuhan
# Processing Record 5 of Set 5 | aksarka
# Processing Record 6 of Set 5 | henties bay
# Processing Record 7 of Set 5 | taizhou
# Processing Record 8 of Set 5 | toribio
# Processing Record 9 of Set 5 | vrangel
# Processing Record 10 of Set 5 | chenzhou
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | oxelosund
# Processing Record 13 of Set 5 | santa leopoldina
# Processing Record 14 of Set 5 | storforshei
# Processing Record 15 of Set 5 | los llanos de aridane
# Processing Record 16 of Set 5 | tanout
# Processing Record 17 of Set 5 | olmos
# Processing Record 18 of Set 5 | beaverlodge
# Processing Record 19 of Set 5 | bembereke
# Processing Record 20 of Set 5 | tucuman
# Processing Record 21 of Set 5 | koungheul
# Processing Record 22 of Set 5 | puerto escondido
# Processing Record 23 of Set 5 | griffith
# Processing Record 24 of Set 5 | praia
# Processing Record 25 of Set 5 | albufeira
# Processing Record 26 of Set 5 | kavaratti
# Processing Record 27 of Set 5 | tiksi
# Processing Record 28 of Set 5 | aklavik
# Processing Record 29 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 30 of Set 5 | airai
# Processing Record 31 of Set 5 | whitehorse
# Processing Record 32 of Set 5 | sarkand
# Processing Record 33 of Set 5 | jiuquan
# Processing Record 34 of Set 5 | sitka
# Processing Record 35 of Set 5 | port-cartier
# Processing Record 36 of Set 5 | victoria
# Processing Record 37 of Set 5 | corinth
# Processing Record 38 of Set 5 | mountain home
# Processing Record 39 of Set 5 | khandyga
# Processing Record 40 of Set 5 | ribeira grande
# Processing Record 41 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 5 | sarkeresztur
# Processing Record 43 of Set 5 | cidreira
# Processing Record 44 of Set 5 | chuy
# Processing Record 45 of Set 5 | hazleton
# Processing Record 46 of Set 5 | mitsamiouli
# Processing Record 47 of Set 5 | sinnamary
# Processing Record 48 of Set 5 | novoagansk
# Processing Record 49 of Set 5 | galle
# Processing Record 50 of Set 5 | siavonga
# Processing Record 1 of Set 6 | sao filipe
# Processing Record 2 of Set 6 | sola
# Processing Record 3 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 6 | karratha
# Processing Record 5 of Set 6 | cardenas
# Processing Record 6 of Set 6 | boende
# Processing Record 7 of Set 6 | ous
# Processing Record 8 of Set 6 | flinders
# Processing Record 9 of Set 6 | pangnirtung
# Processing Record 10 of Set 6 | menongue
# Processing Record 11 of Set 6 | huarmey
# Processing Record 12 of Set 6 | tuatapere
# Processing Record 13 of Set 6 | raudeberg
# Processing Record 14 of Set 6 | firozabad
# Processing Record 15 of Set 6 | ust-kuyga
# Processing Record 16 of Set 6 | mocuba
# Processing Record 17 of Set 6 | goundam
# Processing Record 18 of Set 6 | san julian
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 6 | kyra
# Processing Record 22 of Set 6 | hongjiang
# Processing Record 23 of Set 6 | ahipara
# Processing Record 24 of Set 6 | chiang klang
# Processing Record 25 of Set 6 | poronaysk
# Processing Record 26 of Set 6 | san matias
# Processing Record 27 of Set 6 | kloulklubed
# Processing Record 28 of Set 6 | salalah
# Processing Record 29 of Set 6 | westport
# Processing Record 30 of Set 6 | pustoshka
# Processing Record 31 of Set 6 | tessalit
# Processing Record 32 of Set 6 | ulaangom
# Processing Record 33 of Set 6 | touros
# Processing Record 34 of Set 6 | genc
# Processing Record 35 of Set 6 | garissa
# Processing Record 36 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 6 | pacific grove
# Processing Record 38 of Set 6 | walvis bay
# Processing Record 39 of Set 6 | yeniseysk
# Processing Record 40 of Set 6 | berlevag
# Processing Record 41 of Set 6 | kroya
# Processing Record 42 of Set 6 | stokmarknes
# Processing Record 43 of Set 6 | zhigalovo
# Processing Record 44 of Set 6 | gigmoto
# Processing Record 45 of Set 6 | tecoanapa
# Processing Record 46 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 47 of Set 6 | san patricio
# Processing Record 48 of Set 6 | shenjiamen
# Processing Record 49 of Set 6 | manaure
# Processing Record 50 of Set 6 | cayenne
# Processing Record 1 of Set 7 | mount gambier
# Processing Record 2 of Set 7 | nouadhibou
# Processing Record 3 of Set 7 | porto novo
# Processing Record 4 of Set 7 | paita
# Processing Record 5 of Set 7 | annau
# Processing Record 6 of Set 7 | imeni morozova
# Processing Record 7 of Set 7 | usinsk
# Processing Record 8 of Set 7 | altay
# Processing Record 9 of Set 7 | shetpe
# Processing Record 10 of Set 7 | longyearbyen
# Processing Record 11 of Set 7 | dunedin
# Processing Record 12 of Set 7 | constitucion
# Processing Record 13 of Set 7 | kerema
# Processing Record 14 of Set 7 | olonets
# Processing Record 15 of Set 7 | scarborough
# Processing Record 16 of Set 7 | paramonga
# Processing Record 17 of Set 7 | vikhorevka
# Processing Record 18 of Set 7 | asosa
# Processing Record 19 of Set 7 | saint george
# Processing Record 20 of Set 7 | kodiak
# Processing Record 21 of Set 7 | qaqortoq
# Processing Record 22 of Set 7 | lowicz
# Processing Record 23 of Set 7 | kitimat
# Processing Record 24 of Set 7 | port augusta
# Processing Record 25 of Set 7 | najran
# Processing Record 26 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 7 | marsala
# Processing Record 28 of Set 7 | vardo
# Processing Record 29 of Set 7 | akwatia
# Processing Record 30 of Set 7 | mahebourg
# Processing Record 31 of Set 7 | hami
# Processing Record 32 of Set 7 | bingen
# Processing Record 33 of Set 7 | saint-leu
# Processing Record 34 of Set 7 | khor
# Processing Record 35 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 7 | nizhniy tsasuchey
# Processing Record 37 of Set 7 | obidos
# Processing Record 38 of Set 7 | izhma
# Processing Record 39 of Set 7 | komsomolskiy
# Processing Record 40 of Set 7 | vadlapudi
# Processing Record 41 of Set 7 | ponta do sol
# Processing Record 42 of Set 7 | payson
# Processing Record 43 of Set 7 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 44 of Set 7 | olafsvik
# Processing Record 45 of Set 7 | teahupoo
# Processing Record 46 of Set 7 | cherskiy
# Processing Record 47 of Set 7 | necochea
# Processing Record 48 of Set 7 | manteca
# Processing Record 49 of Set 7 | severnyy
# Processing Record 50 of Set 7 | staroye drozhzhanoye
# Processing Record 1 of Set 8 | nantucket
# Processing Record 2 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 8 | barcelos
# Processing Record 4 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 5 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 8 | kaeo
# Processing Record 7 of Set 8 | thanh hoa
# Processing Record 8 of Set 8 | montague
# Processing Record 9 of Set 8 | natal
# Processing Record 10 of Set 8 | upata
# Processing Record 11 of Set 8 | lavrentiya
# Processing Record 12 of Set 8 | faya
# Processing Record 13 of Set 8 | te anau
# Processing Record 14 of Set 8 | ambilobe
# Processing Record 15 of Set 8 | noumea
# Processing Record 16 of Set 8 | lock haven
# Processing Record 17 of Set 8 | lianran
# Processing Record 18 of Set 8 | ayagoz
# Processing Record 19 of Set 8 | acapulco
# Processing Record 20 of Set 8 | cordoba
# Processing Record 21 of Set 8 | ukiah
# Processing Record 22 of Set 8 | upernavik
# Processing Record 23 of Set 8 | shilka
# Processing Record 24 of Set 8 | iuna
# Processing Record 25 of Set 8 | gaogou
# Processing Record 26 of Set 8 | ixtapa
# Processing Record 27 of Set 8 | yulara
# Processing Record 28 of Set 8 | hay river
# Processing Record 29 of Set 8 | linares
# Processing Record 30 of Set 8 | tomatlan
# Processing Record 31 of Set 8 | broome
# Processing Record 32 of Set 8 | bourail
# Processing Record 33 of Set 8 | tezu
# Processing Record 34 of Set 8 | sangmelima
# Processing Record 35 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 36 of Set 8 | puspokladany
# Processing Record 37 of Set 8 | churapcha
# Processing Record 38 of Set 8 | port lincoln
# Processing Record 39 of Set 8 | thai nguyen
# Processing Record 40 of Set 8 | abramovka
# Processing Record 41 of Set 8 | pimentel
# Processing Record 42 of Set 8 | grindavik
# Processing Record 43 of Set 8 | cam ranh
# Processing Record 44 of Set 8 | hualmay
# Processing Record 45 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 8 | rio grande
# Processing Record 47 of Set 8 | yarada
# Processing Record 48 of Set 8 | dhidhdhoo
# Processing Record 49 of Set 8 | nizhniy kuranakh
# Processing Record 50 of Set 8 | tommot
# Processing Record 1 of Set 9 | ofaqim
# Processing Record 2 of Set 9 | saint anthony
# Processing Record 3 of Set 9 | furstenfeld
# Processing Record 4 of Set 9 | shingu
# Processing Record 5 of Set 9 | mabaruma
# Processing Record 6 of Set 9 | prince rupert
# Processing Record 7 of Set 9 | taltal
# Processing Record 8 of Set 9 | hasaki
# Processing Record 9 of Set 9 | lepaterique
# Processing Record 10 of Set 9 | buon me thuot
# City not found. Skipping...
# Processing Record 11 of Set 9 | plettenberg bay
# Processing Record 12 of Set 9 | privolzhsk
# Processing Record 13 of Set 9 | qasigiannguit
# Processing Record 14 of Set 9 | ust-ordynskiy
# Processing Record 15 of Set 9 | taoudenni
# Processing Record 16 of Set 9 | ensley
# Processing Record 17 of Set 9 | kodinsk
# Processing Record 18 of Set 9 | port hedland
# Processing Record 19 of Set 9 | ewa beach
# Processing Record 20 of Set 9 | peniche
# Processing Record 21 of Set 9 | vila velha
# Processing Record 22 of Set 9 | manoel urbano
# Processing Record 23 of Set 9 | nizhnevartovsk
# Processing Record 24 of Set 9 | dryden
# Processing Record 25 of Set 9 | nome
# Processing Record 26 of Set 9 | maragogi
# Processing Record 27 of Set 9 | hovd
# Processing Record 28 of Set 9 | rangapara
# Processing Record 29 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 30 of Set 9 | alcudia
# Processing Record 31 of Set 9 | skiros
# City not found. Skipping...
# Processing Record 32 of Set 9 | tariba
# Processing Record 33 of Set 9 | isangel
# Processing Record 34 of Set 9 | miri
# Processing Record 35 of Set 9 | kattivakkam
# Processing Record 36 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 9 | itaueira
# Processing Record 38 of Set 9 | narsaq
# Processing Record 39 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 9 | kahului
# Processing Record 41 of Set 9 | zharkent
# Processing Record 42 of Set 9 | sisimiut
# Processing Record 43 of Set 9 | ulaanbaatar
# Processing Record 44 of Set 9 | pedernales
# Processing Record 45 of Set 9 | platteville
# Processing Record 46 of Set 9 | lamu
# Processing Record 47 of Set 9 | waipawa
# Processing Record 48 of Set 9 | tenosique
# Processing Record 49 of Set 9 | zhanakorgan
# Processing Record 50 of Set 9 | laguna
# Processing Record 1 of Set 10 | basco
# Processing Record 2 of Set 10 | pangoa
# Processing Record 3 of Set 10 | port hardy
# Processing Record 4 of Set 10 | xining
# Processing Record 5 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 10 | tsumeb
# Processing Record 7 of Set 10 | chenghai
# Processing Record 8 of Set 10 | honiara
# Processing Record 9 of Set 10 | bowen
# Processing Record 10 of Set 10 | kanpur
# Processing Record 11 of Set 10 | saint-francois
# Processing Record 12 of Set 10 | labuan
# Processing Record 13 of Set 10 | mananjary
# Processing Record 14 of Set 10 | poum
# Processing Record 15 of Set 10 | vaitape
# Processing Record 16 of Set 10 | thunder bay
# Processing Record 17 of Set 10 | pitimbu
# Processing Record 18 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 19 of Set 10 | bose
# Processing Record 20 of Set 10 | semnan
# Processing Record 21 of Set 10 | kholmogory
# Processing Record 22 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 10 | bhag
# Processing Record 24 of Set 10 | santa maria
# Processing Record 25 of Set 10 | cachoeira do sul
# Processing Record 26 of Set 10 | woodburn
# Processing Record 27 of Set 10 | alberton
# Processing Record 28 of Set 10 | edd
# Processing Record 29 of Set 10 | saint-georges
# Processing Record 30 of Set 10 | balkanabat
# Processing Record 31 of Set 10 | shahgarh
# Processing Record 32 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 10 | pauini
# Processing Record 34 of Set 10 | beloha
# Processing Record 35 of Set 10 | caceres
# Processing Record 36 of Set 10 | praia da vitoria
# Processing Record 37 of Set 10 | ovsyanka
# Processing Record 38 of Set 10 | alice springs
# Processing Record 39 of Set 10 | wuzhou
# Processing Record 40 of Set 10 | ilulissat
# Processing Record 41 of Set 10 | guerrero negro
# Processing Record 42 of Set 10 | plouzane
# Processing Record 43 of Set 10 | gizo
# Processing Record 44 of Set 10 | kasama
# Processing Record 45 of Set 10 | caxito
# Processing Record 46 of Set 10 | ahuimanu
# Processing Record 47 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 48 of Set 10 | namatanai
# Processing Record 49 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 50 of Set 10 | ruian
# City not found. Skipping...
# Processing Record 1 of Set 11 | yumen
# Processing Record 2 of Set 11 | ponta delgada
# Processing Record 3 of Set 11 | ortigueira
# Processing Record 4 of Set 11 | trofors
# Processing Record 5 of Set 11 | alekseyevka
# Processing Record 6 of Set 11 | roseburg
# Processing Record 7 of Set 11 | antofagasta
# Processing Record 8 of Set 11 | misratah
# Processing Record 9 of Set 11 | sakaraha
# Processing Record 10 of Set 11 | kiama
# Processing Record 11 of Set 11 | beringovskiy
# Processing Record 12 of Set 11 | podosinovets
# Processing Record 13 of Set 11 | bandarbeyla
# Processing Record 14 of Set 11 | muros
# Processing Record 15 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 11 | yerbogachen
# Processing Record 17 of Set 11 | burnie
# Processing Record 18 of Set 11 | meulaboh
# Processing Record 19 of Set 11 | tura
# Processing Record 20 of Set 11 | lakes entrance
# Processing Record 21 of Set 11 | naze
# Processing Record 22 of Set 11 | fort nelson
# Processing Record 23 of Set 11 | dingle
# Processing Record 24 of Set 11 | inhambane
# Processing Record 25 of Set 11 | aswan
# Processing Record 26 of Set 11 | sidi bu zayd
# City not found. Skipping...
# Processing Record 27 of Set 11 | russell
# Processing Record 28 of Set 11 | letnyaya stavka
# Processing Record 29 of Set 11 | krasnoturansk
# Processing Record 30 of Set 11 | jiayuguan
# Processing Record 31 of Set 11 | akyab
# Processing Record 32 of Set 11 | kasongo-lunda
# Processing Record 33 of Set 11 | zhangye
# Processing Record 34 of Set 11 | bandundu
# Processing Record 35 of Set 11 | huntsville
# Processing Record 36 of Set 11 | miles city
# Processing Record 37 of Set 11 | sorland
# Processing Record 38 of Set 11 | chikwawa
# Processing Record 39 of Set 11 | pangkalanbuun
# Processing Record 40 of Set 11 | falam
# Processing Record 41 of Set 11 | det udom
# Processing Record 42 of Set 11 | norman wells
# Processing Record 43 of Set 11 | visby
# Processing Record 44 of Set 11 | bilma
# Processing Record 45 of Set 11 | laval
# Processing Record 46 of Set 11 | vercelli
# Processing Record 47 of Set 11 | seymchan
# Processing Record 48 of Set 11 | sfantu gheorghe
# Processing Record 49 of Set 11 | zanatepec
# City not found. Skipping...
# Processing Record 50 of Set 11 | yarim
# Processing Record 1 of Set 12 | hof
# Processing Record 2 of Set 12 | nong phai
# Processing Record 3 of Set 12 | teguldet
# Processing Record 4 of Set 12 | jinka
# Processing Record 5 of Set 12 | tombouctou
# Processing Record 6 of Set 12 | livingston
# Processing Record 7 of Set 12 | bonito
# Processing Record 8 of Set 12 | atherton
# Processing Record 9 of Set 12 | gorontalo
# Processing Record 10 of Set 12 | havre-saint-pierre
# Processing Record 11 of Set 12 | kelo
# Processing Record 12 of Set 12 | arman
# Processing Record 13 of Set 12 | sakaiminato
# Processing Record 14 of Set 12 | mpika
# Processing Record 15 of Set 12 | barbastro
# Processing Record 16 of Set 12 | morondava
# Processing Record 17 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 12 | oxford
# Processing Record 19 of Set 12 | wasilla
# Processing Record 20 of Set 12 | kharsawan
# Processing Record 21 of Set 12 | saryg-sep
# Processing Record 22 of Set 12 | east stroudsburg
# Processing Record 23 of Set 12 | inyonga
# Processing Record 24 of Set 12 | clyde river
# Processing Record 25 of Set 12 | rocha
# Processing Record 26 of Set 12 | palmer
# Processing Record 27 of Set 12 | beyneu
# Processing Record 28 of Set 12 | camacha
# Processing Record 29 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 12 | punta cardon
# Processing Record 31 of Set 12 | bathsheba
# Processing Record 32 of Set 12 | mafinga
# Processing Record 33 of Set 12 | cozumel
# Processing Record 34 of Set 12 | vernon
# Processing Record 35 of Set 12 | zaraza
# Processing Record 36 of Set 12 | nsanje
# Processing Record 37 of Set 12 | hauterive
# Processing Record 38 of Set 12 | marovoay
# Processing Record 39 of Set 12 | kismayo
# Processing Record 40 of Set 12 | amahai
# Processing Record 41 of Set 12 | north bend
# Processing Record 42 of Set 12 | scottsbluff
# Processing Record 43 of Set 12 | iringa
# Processing Record 44 of Set 12 | mareeba
# Processing Record 45 of Set 12 | aguilas
# Processing Record 46 of Set 12 | moranbah
# Processing Record 47 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 12 | jiaozuo
# Processing Record 49 of Set 12 | mahibadhoo
# Processing Record 50 of Set 12 | codrington
# Processing Record 1 of Set 13 | kamina
# Processing Record 2 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 13 | acajutla
# Processing Record 4 of Set 13 | san felipe
# Processing Record 5 of Set 13 | parfenyevo
# Processing Record 6 of Set 13 | susanville
# Processing Record 7 of Set 13 | bitung
# Processing Record 8 of Set 13 | pringsewu
# Processing Record 9 of Set 13 | trinidad
# Processing Record 10 of Set 13 | jinan
# Processing Record 11 of Set 13 | gitega
# Processing Record 12 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 13 of Set 13 | candating
# Processing Record 14 of Set 13 | rawson
# Processing Record 15 of Set 13 | marzuq
# Processing Record 16 of Set 13 | luanda
# Processing Record 17 of Set 13 | bisira
# Processing Record 18 of Set 13 | kruisfontein
# Processing Record 19 of Set 13 | taksimo
# Processing Record 20 of Set 13 | san pedro
# Processing Record 21 of Set 13 | newport
# Processing Record 22 of Set 13 | yeppoon
# Processing Record 23 of Set 13 | svetlogorsk
# Processing Record 24 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 25 of Set 13 | kaspiyskiy
# Processing Record 26 of Set 13 | doha
# Processing Record 27 of Set 13 | minab
# Processing Record 28 of Set 13 | chany
# Processing Record 29 of Set 13 | taicheng
# Processing Record 30 of Set 13 | yurga
# Processing Record 31 of Set 13 | san ignacio
# Processing Record 32 of Set 13 | adre
# Processing Record 33 of Set 13 | roald
# Processing Record 34 of Set 13 | hambantota
# Processing Record 35 of Set 13 | muhlacker
# Processing Record 36 of Set 13 | almaty
# Processing Record 37 of Set 13 | nemuro
# Processing Record 38 of Set 13 | lasa
# Processing Record 39 of Set 13 | batemans bay
# Processing Record 40 of Set 13 | valpacos
# Processing Record 41 of Set 13 | kalianget
# Processing Record 42 of Set 13 | sohag
# Processing Record 43 of Set 13 | luang prabang
# Processing Record 44 of Set 13 | piracuruca
# Processing Record 45 of Set 13 | bukene
# Processing Record 46 of Set 13 | tenango
# Processing Record 47 of Set 13 | tirana
# Processing Record 48 of Set 13 | el corpus
# Processing Record 49 of Set 13 | glenwood springs
# Processing Record 50 of Set 13 | rio branco
# Processing Record 1 of Set 14 | monkey bay
# Processing Record 2 of Set 14 | nyurba
# Processing Record 3 of Set 14 | minbu
# Processing Record 4 of Set 14 | mount isa
# Processing Record 5 of Set 14 | nishihara
# Processing Record 6 of Set 14 | san luis
# Processing Record 7 of Set 14 | amberieu-en-bugey
# Processing Record 8 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 14 | eureka
# Processing Record 10 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 14 | andenes
# Processing Record 12 of Set 14 | jiroft
# City not found. Skipping...
# Processing Record 13 of Set 14 | adrar
# Processing Record 14 of Set 14 | kupang
# Processing Record 15 of Set 14 | saint-pierre
# Processing Record 16 of Set 14 | anori
# Processing Record 17 of Set 14 | impfondo
# Processing Record 18 of Set 14 | waingapu
# Processing Record 19 of Set 14 | bac ninh
# Processing Record 20 of Set 14 | batticaloa
# Processing Record 21 of Set 14 | gondanglegi
# Processing Record 22 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 14 | gunjur
# Processing Record 25 of Set 14 | rognan
# Processing Record 26 of Set 14 | bulgan
# Processing Record 27 of Set 14 | omboue
# Processing Record 28 of Set 14 | juneau
# Processing Record 29 of Set 14 | port keats
# Processing Record 30 of Set 14 | tambopata
# Processing Record 31 of Set 14 | jacareacanga
# Processing Record 32 of Set 14 | alpena
# Processing Record 33 of Set 14 | lamar
# Processing Record 34 of Set 14 | fukue
# Processing Record 35 of Set 14 | alta floresta
# Processing Record 36 of Set 14 | itoman
# Processing Record 37 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 38 of Set 14 | iwanai
# Processing Record 39 of Set 14 | senanga
# Processing Record 40 of Set 14 | cimitarra
# Processing Record 41 of Set 14 | vikesa
# Processing Record 42 of Set 14 | mount pleasant
# Processing Record 43 of Set 14 | concepcion
# Processing Record 44 of Set 14 | phan thiet
# Processing Record 45 of Set 14 | falun
# Processing Record 46 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 14 | vazhiny
# Processing Record 48 of Set 14 | manaus
# Processing Record 49 of Set 14 | bertoua
# Processing Record 50 of Set 14 | pokanayevka
# City not found. Skipping...
# Processing Record 1 of Set 15 | cabangahan
# Processing Record 2 of Set 15 | ahome
# Processing Record 3 of Set 15 | college
# Processing Record 4 of Set 15 | sawtell
# Processing Record 5 of Set 15 | pirassununga
# Processing Record 6 of Set 15 | riyadh
# Processing Record 7 of Set 15 | manturovo
# Processing Record 8 of Set 15 | okhotsk
# Processing Record 9 of Set 15 | sisophon
# Processing Record 10 of Set 15 | lodja
# Processing Record 11 of Set 15 | raga
# Processing Record 12 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 13 of Set 15 | outlook
# Processing Record 14 of Set 15 | el alto
# Processing Record 15 of Set 15 | ambon
# Processing Record 16 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 15 | vallenar
# Processing Record 18 of Set 15 | jalingo
# Processing Record 19 of Set 15 | la asuncion
# Processing Record 20 of Set 15 | erdenet
# Processing Record 21 of Set 15 | verkhnevilyuysk
# Processing Record 22 of Set 15 | konevo
# Processing Record 23 of Set 15 | marawi
# Processing Record 24 of Set 15 | tautira
# Processing Record 25 of Set 15 | el faiyum
# City not found. Skipping...
# Processing Record 26 of Set 15 | trairi
# Processing Record 27 of Set 15 | corrente
# Processing Record 28 of Set 15 | hervey bay
# Processing Record 29 of Set 15 | steinbach
# Processing Record 30 of Set 15 | kenora
# Processing Record 31 of Set 15 | bairiki
# Processing Record 32 of Set 15 | orange cove
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Ostrovnoy  68.0531   39.5131     14.14        86          96       22.17
# 1     Thompson  55.7435  -97.8558    -11.04        64          20        4.61
# 2  Grand Gaube -20.0064   57.6608     79.38        80          84        3.00
# 3        Alofi -19.0595 -169.9187     75.09        94         100        4.61
# 4     Luderitz -26.6481   15.1594     68.59        75          16        4.94
# 5       Lompoc  34.6391 -120.4579     73.09        44           0        5.75
# 6       Castro -24.7911  -50.0119     77.77        66          68        7.36
# 7   Skibbereen  51.5500   -9.2667     51.12        82          94       19.37
# 8      Mataura -46.1927  168.8643     39.47        99           4        2.01
# 9       Albany  42.6001  -73.9662     27.82        50          18        4.00
#
#   Country Current Description
# 0      RU     overcast clouds
# 1      CA          few clouds
# 2      MU       broken clouds
# 3      NU     overcast clouds
# 4      NA          few clouds
# 5      US           clear sky
# 6      BR       broken clouds
# 7      IE     overcast clouds
# 8      NZ           clear sky
# 9      US          few clouds

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ostrovnoy      RU  68.0531   39.5131     14.14        86          96
# 1     Thompson      CA  55.7435  -97.8558    -11.04        64          20
# 2  Grand Gaube      MU -20.0064   57.6608     79.38        80          84
# 3        Alofi      NU -19.0595 -169.9187     75.09        94         100
# 4     Luderitz      NA -26.6481   15.1594     68.59        75          16
# 5       Lompoc      US  34.6391 -120.4579     73.09        44           0
# 6       Castro      BR -24.7911  -50.0119     77.77        66          68
# 7   Skibbereen      IE  51.5500   -9.2667     51.12        82          94
# 8      Mataura      NZ -46.1927  168.8643     39.47        99           4
# 9       Albany      US  42.6001  -73.9662     27.82        50          18
#
#    Wind Speed Current Description
# 0       22.17     overcast clouds
# 1        4.61          few clouds
# 2        3.00       broken clouds
# 3        4.61     overcast clouds
# 4        4.94          few clouds
# 5        5.75           clear sky
# 6        7.36       broken clouds
# 7       19.37     overcast clouds
# 8        2.01           clear sky
# 9        4.00          few clouds

# %%
# Create the output file (CSV).
output_data_file = "..\Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
